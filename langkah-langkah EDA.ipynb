# %% [markdown]
# # Langkah-langkah EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - Menampilkan data
#     - disini saya memakai data penjualan tiket film per tahunnya. Tidak hanya penjualannya, melainkan inflasi tiket penjualan pun juga ikut dimuat.

# %%
data = pd.read_csv(r'C:\Users\USER\Downloads\data_film.csv')
data
# Out:
#      index            Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0        0        Adventure  1995               29   771507571     177358047
# 1        1        Adventure  1996               34  1290490033     291966054
# 2        2        Adventure  1997               23   881902843     192135684
# 3        3        Adventure  1998               29  1614467732     344236174
# 4        4        Adventure  1999               27  1612432107     317407880
# ..     ...              ...   ...              ...         ...           ...
# 295    295  Multiple Genres  2017                5     4614134        514394
# 296    296  Multiple Genres  2018                3     4787450        533717
# 297    297          Reality  2014                1       16826          2059
# 298    298          Reality  2015                3      604870         71751
# 299    299          Reality  2018                1        2027           225
#
# ...

# %% [markdown]
# - Basic information
#     - basic information memuat tipe data pada tiap kolom dari dataset, dan menghitung pula null dari tiap kolomnya. Selain itu, saya juga menampilkan 5 baris pertama dan terakhir dari data ini.

# %%
basic_info = data.info()
basic_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   index                                           300 non-null    int64
#  1   Genre                                           300 non-null    object
#  2   Year                                            300 non-null    int64
#  3   Movies Released                                 300 non-null    int64
#  4   Gross                                           300 non-null    int64
#  5   Tickets Sold                                    300 non-null    int64
#  6   Inflation-Adjusted Gross                        300 non-null    int64
#  7   Top Movie                                       300 non-null    object
#  8   Top Movie Gross (That Year)                     300 non-null    int64
# ...

# %%
info_awal = data.head()
info_awal
# Out:
#    index      Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0      0  Adventure  1995               29   771507571     177358047
# 1      1  Adventure  1996               34  1290490033     291966054
# 2      2  Adventure  1997               23   881902843     192135684
# 3      3  Adventure  1998               29  1614467732     344236174
# 4      4  Adventure  1999               27  1612432107     317407880
#
#    Inflation-Adjusted Gross                            Top Movie  \
# 0                1590901682                            Toy Story
# 1                2618935504                     Independence Day
# 2                1723457085                         Men in Black
# 3                3087798481                           Armageddon
# 4                2847148684  Star Wars Ep. I: The Phantom Menace
#
#    Top Movie Gross (That Year)  Top Movie Inflation-Adjusted Gross (That Year)
# 0                    150148222                                    3.096160e+08
# ...

# %%
info_akhir = data.tail()
info_akhir
# Out:
#      index            Genre  Year  Movies Released    Gross  Tickets Sold  \
# 295    295  Multiple Genres  2017                5  4614134        514394
# 296    296  Multiple Genres  2018                3  4787450        533717
# 297    297          Reality  2014                1    16826          2059
# 298    298          Reality  2015                3   604870         71751
# 299    299          Reality  2018                1     2027           225
#
#      Inflation-Adjusted Gross           Top Movie  \
# 295                   4614114   2017 Oscar Shorts
# 296                   4787441   2018 Oscar Shorts
# 297                     18469       The Principle
# 298                    643606  Benpao Ba! Xiongdi
# 299                      2018    The Cage Fighter
#
#      Top Movie Gross (That Year)  \
# 295                      2835355
# 296                      3508777
# 297                        16826
# 298                       309297
# 299                         2027
#
# ...

# %% [markdown]
# - Cek nilai duplikat dan nilai unik
#     - Menghitung banyaknya nilai null dan nilai duplikat dalam data ini.

# %%
check_duplikat = data.duplicated().sum()
check_duplikat
# Out:
# 0

# %%
check_unique = data.nunique()
check_unique
# Out:
# index                                             300
# Genre                                              14
# Year                                               24
# Movies Released                                   110
# Gross                                             300
# Tickets Sold                                      300
# Inflation-Adjusted Gross                          300
# Top Movie                                         287
# Top Movie Gross (That Year)                       300
# Top Movie Inflation-Adjusted Gross (That Year)    300
# dtype: int64

# %% [markdown]
# - Tampilkan atau visualisasikan jumlah nilai unik
#     - menampilkan diagram bar nilai unik dan juga menampilkan jumlahnya dari tiap kolom dari data tersebut.

# %%
# Visualisasi jumlah nilai unik di setiap kolom
check_unique.plot(kind='bar')

plt.title('Jumlah Nilai Unik per Kolom')
plt.ylabel('Jumlah Nilai Unik')

for index, value in enumerate(check_unique):
    plt.text(index, value, str(value), ha='center', va='bottom')
    
plt.show()

# %% [markdown]
# - Menemukan null values

# %%
check_null = data.isnull().sum()
check_null
# Out:
# index                                             0
# Genre                                             0
# Year                                              0
# Movies Released                                   0
# Gross                                             0
# Tickets Sold                                      0
# Inflation-Adjusted Gross                          0
# Top Movie                                         0
# Top Movie Gross (That Year)                       0
# Top Movie Inflation-Adjusted Gross (That Year)    0
# dtype: int64

# %% [markdown]
# - Mengetahui tipe data dari dataset yang sedang dieksplorasi untuk memeprmudah proses
#     - Menggunakan .dtypes untuk mencari tahu tipe data nya.

# %%
data.dtypes
# Out:
# index                                               int64
# Genre                                              object
# Year                                                int64
# Movies Released                                     int64
# Gross                                               int64
# Tickets Sold                                        int64
# Inflation-Adjusted Gross                            int64
# Top Movie                                          object
# Top Movie Gross (That Year)                         int64
# Top Movie Inflation-Adjusted Gross (That Year)    float64
# dtype: object

# %% [markdown]
# - Filter data
#     - Disini saya ingin mencari tahu, film apa saja yang dirilis diatas tahun 2000.

# %%
# Memfilter data untuk tahun di atas 2000
filtered_df = data[data['Year'] > 2000]
filtered_df
# Out:
#      index            Genre  Year  Movies Released       Gross  Tickets Sold  \
# 6        6        Adventure  2001               32  2268870844     400844935
# 7        7        Adventure  2002               45  2818919526     485184060
# 8        8        Adventure  2003               46  2424131447     402011823
# 9        9        Adventure  2004               47  2887833719     465029564
# 10      10        Adventure  2005               43  2541162317     396437158
# ..     ...              ...   ...              ...         ...           ...
# 295    295  Multiple Genres  2017                5     4614134        514394
# 296    296  Multiple Genres  2018                3     4787450        533717
# 297    297          Reality  2014                1       16826          2059
# 298    298          Reality  2015                3      604870         71751
# 299    299          Reality  2018                1        2027           225
#
# ...

# %% [markdown]
# - Boxplot
#     - Memvisualisasikan Gross atau penjualan tiket dari film. Dengan ini, kita bisa mengetahui perkiraan penjualan tiket dari semua film ada di kisaran berapa dan juga mengetahui pencilan atau outlier penjualan tiket dari data tersebut.

# %%
import seaborn as sns

# Membuat box plot untuk kolom 'Gross'
sns.boxplot(x='Gross', data=data)
plt.title('Box Plot of Gross')
plt.show()

# %% [markdown]
# - Korelasi
#     - untuk melihat hubungan linear antara variabel-variabel numerik di dalam dataset.

# %%
data_numerical = data.select_dtypes(include=['float64','int64'])

matriks_korelasi = data_numerical.corr()

plt.figure(figsize=(10, 8))  # Menyesuaikan ukuran plot agar lebih jelas
sns.heatmap(matriks_korelasi, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
